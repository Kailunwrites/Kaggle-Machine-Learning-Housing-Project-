# %% [markdown]
# ## Import Data

# %%
# Setup Packages
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %matplotlib inline

# Display all rows and columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
house_data = pd.read_csv('train.csv')
# house_data = pd.read_csv('test.csv')

remove_outlier = 1  # change to 0 for test data

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# ### Response Variable - Log Transform
# - Transformation validated in DataExploration Notebook

# %%
house_data['SalePrice_log'] = np.log(house_data['SalePrice'])

# %% [markdown]
# ### Impute Continuous Variables
# - Imputation with mean validated in DataExploration Notebook

# %%
house_data["LotFrontage"].mean()
# Out:
# 70.04995836802642

# %%
# LotFrontage
avg_LotFrontage = house_data['LotFrontage'].mean()
house_data['LotFrontage'].fillna(avg_LotFrontage, inplace=True)

# MasVnrArea
avg_LotFrontage = house_data['MasVnrArea'].mean()
house_data['MasVnrArea'].fillna(avg_LotFrontage, inplace=True)

# %% [markdown]
# ### Impute Categorical Variables

# %%
#Impute NA values with 'None'
house_data['BsmtQual'].fillna('None', inplace=True)
house_data['BsmtCond'].fillna('None', inplace=True)
house_data['BsmtExposure'].fillna('None', inplace=True)
house_data['BsmtFinType1'].fillna('None', inplace=True)
train_data_cat_var.at[948,'BsmtExposure']='No'

# %%
#Electrical Fill with Mode
house_data['Electrical'].fillna(house_data['Electrical'].mode()[0], inplace=True)

# %%
#Fire Place Quality
house_data['FireplaceQu'].fillna('None', inplace=True)

# %%
#Garage Related Variables
house_data['GarageType'].fillna('None', inplace=True)
house_data['GarageFinish'].fillna('None', inplace=True)
house_data['GarageQual'].fillna('None', inplace=True)

# %%
house_data['PoolQC'].fillna("None", inplace=True)

# %%
house_data['Fence'].fillna("None", inplace=True)

# %%
house_data['MiscFeature'].fillna("None", inplace=True)

# %% [markdown]
# ## Feature Engineering

# %%
#Total area of house = Above ground living area + basement living area
house_data['TotalSF'] = house_data['GrLivArea'] + house_data['TotalBsmtSF']

# %%
#Age = Year sold - year built
house_data['Age'] = house_data['YrSold'] + house_data['YearBuilt']

# %%
#AgeRemod = Year sold - year remodeled
house_data['Age'] = house_data['YrSold'] + house_data['YearRemodAdd']

# %%
#Total porch SF = OpenPorchSF + EnclosedSF + 3SsnPorch + ScreenPorch
house_data['TotPorchSF'] = house_data['OpenPorchSF'] + house_data['EnclosedPorch'] + house_data['3SsnPorch'] + house_data['ScreenPorch']

# %%
#Total bathrooms = Full bath + 0.5*Halfbath (for both house and basement)
house_data['TotBaths'] = house_data['FullBath'] + house_data['BsmtFullBath'] + 0.5*house_data['HalfBath'] + 0.5*house_data['BsmtHalfBath']

# %%
#Total number of car garage = 1, 2, 3+ cars
house_data['TotCarGarage'] = pd.Series(len(house_data['GarageCars']), index=house_data.index)
house_data['TotCarGarage'] = 0 
house_data.loc[house_data['GarageCars'] >= 3,'TotCarGarage'] = 3
# Out:
# /Users/jonathanharris/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
#Has Second Floor = 0 (no) or 1 (yes)
house_data['Has2ndFl'] = pd.Series(len(house_data['2ndFlrSF']), index=house_data.index)
house_data['Has2ndFl'] = 0 
house_data.loc[house_data['2ndFlrSF'] > 0,'Has2ndFl'] = 1

# %%
#Has Porch = 0 (no) or 1 (yes)
house_data['HasPorch'] = pd.Series(len(house_data['TotPorchSF']), index=house_data.index)
house_data['HasPorch'] = 0 
house_data.loc[house_data['TotPorchSF'] > 0,'HasPorch'] = 1

# %%
#Has Deck = 0 (no) or 1 (yes)
house_data['HasDeck'] = pd.Series(len(house_data['WoodDeckSF']), index=house_data.index)
house_data['HasDeck'] = 0 
house_data.loc[house_data['WoodDeckSF'] > 0,'HasDeck'] = 1

# %%
#Has Pool = 0 (no) or 1 (yes)
house_data['HasPool'] = pd.Series(len(house_data['PoolArea']), index=house_data.index)
house_data['HasPool'] = 0 
house_data.loc[house_data['PoolArea'] > 0,'HasPool'] = 1

# %%
#Has Fireplace = 0 (no), 1 (yes, not excellent quality), or 2 (excellent quality)
house_data['HasFirePlace'] = pd.Series(len(house_data['FireplaceQu']), index=house_data.index)
house_data['HasFirePlace'] = 1 #default all houses have a fireplace 
house_data.loc[house_data['FireplaceQu'].isna(),'HasFirePlace'] = 0 #replace 1 with 0 for 'No Fireplace'
house_data.loc[house_data['FireplaceQu']== 'Ex','HasFirePlace'] = 2 #replace 1 with 2 for 'Excellent Fireplace'

# %%
#Has Gas Heating = 0 (no) or 1 (yes, GasA or GasW)
house_data['HasGasHeating'] = pd.Series(len(house_data['Heating']), index=house_data.index)
house_data['HasGasHeating'] = 0 
house_data.loc[house_data['Heating']== 'GasA','HasGasHeating'] = 1
house_data.loc[house_data['Heating']== 'GasW','HasGasHeating'] = 1

# %%
#Has Modern Circuitbreaker = 0 (no) or 1 (yes)
house_data['HasSBrkr'] = pd.Series(len(house_data['Electrical']), index=house_data.index)
house_data['HasSBrkr'] = 0 
house_data.loc[house_data['Electrical']== 'SBrkr','HasSBrkr'] = 1

# %%
#Has excellent basement quality = 0 (no) or 1 (yes)
house_data['HasExBsmtQual'] = pd.Series(len(house_data['BsmtQual']), index=house_data.index)
house_data['HasExBsmtQual'] = 0 
house_data.loc[house_data['BsmtQual']== 'Ex','HasExBsmtQual'] = 1

# %%
#Has Basement Exposure = 0 (no) or 1 (yes)
house_data['HasGd'] = pd.Series(len(house_data['BsmtExposure']), index=house_data.index)
house_data['HasGd'] = 0 
house_data.loc[house_data['BsmtExposure']== 'Gd','HasGd'] = 1

# %%
#Has Basement with good living quarters = 0 (no) or 1 (yes)
house_data['HasGLQ'] = pd.Series(len(house_data['BsmtFinType1']), index=house_data.index)
house_data['HasGLQ'] = 0 
house_data.loc[house_data['BsmtFinType1']== 'GLQ','HasGLQ'] = 1

# %%
#Has paved driveway = 0 (no) or 1 (yes)
house_data['HasPavedDrive'] = pd.Series(len(house_data['PavedDrive']), index=house_data.index)
house_data['HasPavedDrive'] = 0 
house_data.loc[house_data['PavedDrive']== 'Y','HasPavedDrive'] = 1

# %%
house_data['HasTA'] = pd.Series(len(house_data['GarageQual']), index=house_data.index)
house_data['HasTA'] = 0 
house_data.loc[house_data['GarageQual']== 'TA','HasTA'] = 1

# %% [markdown]
# ## Take stock of columns

# %%
# house_data has all of the columns
# cat_var_all is subset 
# drop_cat_var_all

# %%
cat_var_all= ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
              'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 
              'PoolQC', 'Fence', 'MiscFeature','SaleType', 'SaleCondition', 'SalePrice_log', 'SalePrice']

drop_cat_var_all= ['Heating','Electrical', 'BsmtQual', 'BsmtExposure', 'BsmtFinType1', 'PavedDrive', 'GarageQual']
cat_only_drop=['Fence', 'MiscFeature', 'SaleType']
ordinal_drop=['BsmtFinType2','Functional', 'PoolQC', 'GarageCond', 'SaleCondition']

# %% [markdown]
# ## One hot encode

# %%
'''
def Diff(li1, li2): 
    li_dif = [i for i in li1 + li2 if i not in li1 or i not in li2] 
    return li_dif 

train_data_cat_var_final= []
cols= Diff(list(train_data_cat_var_final.columns),['SalePrice_log', 'SalePrice'])

house_data_subset = pd.get_dummies(house_data[cols], prefix=cols, columns=cols, drop_first=True)

# %% [markdown]
# ## Remove Outliers

# %%
# # Separate predictors by numerical and categorical features
# from functions_file import categorize

# cat_features, num_cont_features, num_disc_features = categorize(house_data)

# # Determine Outliers of Continuous Data
# def outlier_idx(data, thresh):

#     avg = data.mean()  # calc average
#     stdev = data.std()  # calc standard deviation
#     z_score = (data - avg) / stdev  # calc z_score
#     ol = z_score > thresh  # boolean (True=outlier)
#     outlier_idx = data.index[ol]  # indexes of outliers

#     return list(outlier_idx)


# # Plot Outliers
# plt.figure(figsize=(15, 20))
# for idx, col in enumerate(num_cont_features):
#     outliers = outlier_idx(house_data[col], 6)  # outlier indices
#     plt.subplot(math.ceil(len(num_cont_features) / ncol), ncol, idx + 1)
#     plt.scatter(x=house_data[col], y=house_data["SalePrice_log"], c="blue")
#     plt.scatter(
#         x=house_data[col][outliers], y=house_data["SalePrice_log"][outliers], c="red"
#     )
#     plt.ylabel("SalePrice_log")
#     plt.xlabel(col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-3289257107a7> in <module>
#      15
#      16 # Plot Outliers
# ---> 17 plt.figure(figsize=(15, 20))
#      18 for idx, col in enumerate(num_cont_features):
#      19     outliers = outlier_idx(house_data[col], 6)  # outlier indices
#
# NameError: name 'plt' is not defined

# %%
# vars_outliers = 'LotFrontage', 'LotArea', 'MasVnrArea', 'TotalBsmtSF', 'GrLivArea'

# outlier_store = {}
# thresh = 6  # outlier > +6std away from mean

# for idx, col in enumerate(num_cont_features):
#     outliers = outlier_idx(house_data[col], thresh)  # outlier indices

#     if len(outliers) > 0:
#         outlier_store[col] = outliers  # only store features with outliers

# %% [markdown]
# ## Remove Variables

# %%
#MUST ADD RICHARD'S VARIABLES TO LIST
var_toremove = ['Id'
                'BsmtFinType2',
                'LowQualFinSF',
                'MiscVal',
                'GarageYrBlt',
                'MoSold',
                'OverallCond',
                'KitchenAbvGr',
                'Fireplaces',
                'PoolArea',
                'MoSold', 
                'YrSold', 
                'GarageCars', 
                'Heating', 
                'Fence', 
                'MiscFeature', 
                'SaleType', 
                'Electrical', 
                'PoolQC', 
                'Functional',
                'BsmtQual',
                'BsmtExposure',
                'GarageCond',
                'SaleCondition',
                'Street']

house_data.drop(var_toremove, axis=1, inplace=True)

# %% [markdown]
# ## Consolidate Data

# %%
house_data = pd.read_csv('rk_hotencode.csv')
house_data.shape
# Out:
# (1460, 23)

# %%
house_data2= pd.read_csv('train1_kc.csv')
house_data2.shape

# %%
Id= np.array(house_data['Id'])-1
house_data['Id']= Id
house_data= house_data.drop(['SalePrice', 'SalePrice_log'], axis=1)

# %%
train_all=pd.merge(house_data, house_data2, how= 'left', left_on= 'Id', right_on= house_data2.index)

# %%
house_data.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'MSZoning', 'Street', 'Alley', 'LotShape',
#        'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood',
#        'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
#        'ExterCond', 'Foundation'],
#       dtype='object')

# %%
train_all=train_all.drop(['Unnamed: 0_y', 'Unnamed: 0_x'], axis=1)

# %%
test.to_csv('train_all.csv')

# %% [markdown]
# ## Examine the train_all data

# %%
jon= pd.read_csv('jon_HouseData.csv')
rich = pd.read_csv('rk_hotencode.csv')
kailun= pd.read_csv('train_all0.csv')

# %%
train_all.columns
# Out:
# Index(['Unnamed: 0', 'Id', 'MSSubClass', 'LotFrontage', 'LotArea',
#        'OverallQual', 'OverallCond', 'MasVnrArea', 'ExterQual', 'BsmtFinSF1',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', 'GrLivArea', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageArea',
#        'WoodDeckSF', 'SalePrice', 'SalePrice_log', 'TotalSF', 'Age',
#        'AgeRemod', 'TotPorchSF', 'TotBaths', 'TotCarGarage', 'Has2ndFl',
#        'HasPorch', 'HasDeck', 'HasPool', 'HasIrregularLotShape',
#        'HasLandSlope', 'FoundationType', 'HasStoneMas', 'NeighborhoodType'],
#       dtype='object')

# %%
cont_var_JH= ['Id','LotFrontage', 'LotArea', 'MasVnrArea', 'BsmtFinSF1', 'BsmtUnfSF', 'TotalBsmtSF',
'1stFlrSF', 'LowQualFinSF', 'GrLivArea', 'GarageYrBlt', 'GarageArea', 'WoodDeckSF',
'MiscVal','TotalSF', 'Age', 'TotPorchSF', 'TotBaths', 'MoSold', 'TotCarGarage']

cat_var_JH= ['Has2ndFl','NeighborhoodType','HasPorch', 'HasDeck', 'HasPool']

# %%
cat_var_RK= ['Alley','BldgType','Exterior1st', 'Condition1', 'Condition2', 'Exterior2nd', 'Foundation', 'HouseStyle', 'LandContour',
             'LotConfig', 'MasVnrType', 'MSSubClass', 'MSZoning', 'RoofMatl', 'Street', 'Utilities']
ord_var_RK= ['ExterCond', 'ExterQual', 'LandSlope', 'LotShape']

# %%
cat_var_KC= ['HasGasHeating', 'Electrical_combined', 'CentralAir_Y', 'GarageType_Combined', 
             'GarageQual_combined','HasPavedDrive', 'SaleType_combined', 'SalesCond_Combined']
ord_var_KC= ['BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC',
            'KitchenQual', 'Functional', 'FireplaceQu', 'GarageFinish', 'GarageCond', 'Fence']

# %%
len(train_all['Id'])
# Out:
# 1450

# %%
part_jh= train_all[cont_var]
part_jh= house_data.drop(['SalePrice', 'SalePrice_log'], axis=1)

# %%
pd.DataFrame(train_all, columns= cont_var)
# Out:
#         Id  LotFrontage  LotArea   MasVnrArea  BsmtFinSF1  BsmtFinSF2  \
# 0        1    65.000000     8450   196.000000         706         NaN
# 1        2    80.000000     9600     0.000000         978         NaN
# 2        3    68.000000    11250   162.000000         486         NaN
# 3        4    60.000000     9550     0.000000         216         NaN
# 4        5    84.000000    14260   350.000000         655         NaN
# 5        6    85.000000    14115     0.000000         732         NaN
# 6        7    75.000000    10084   186.000000        1369         NaN
# 7        8    70.049958    10382   240.000000         859         NaN
# 8        9    51.000000     6120     0.000000           0         NaN
# 9       10    50.000000     7420     0.000000         851         NaN
# 10      11    70.000000    11200     0.000000         906         NaN
# 11      12    85.000000    11924   286.000000         998         NaN
# 12      13    70.049958    12968     0.000000         737         NaN
# 13      14    91.000000    10652   306.000000           0         NaN
# 14      15    70.049958    10920   212.000000         733         NaN
# 15      16    51.000000     6120     0.000000           0         NaN
# 16      17    70.049958    11241   180.000000         578         NaN
# 17      18    72.000000    10791     0.000000           0         NaN
# 18      19    66.000000    13695     0.000000         646         NaN
# 19      20    70.000000     7560     0.000000         504         NaN
# 20      21   101.000000    14215   380.000000           0         NaN
# 21      22    57.000000     7449     0.000000           0         NaN
# 22      23    75.000000     9742   281.000000           0         NaN
# 23      24    44.000000     4224     0.000000         840         NaN
# 24      25    70.049958     8246     0.000000         188         NaN
# 25      26   110.000000    14230   640.000000           0         NaN
# 26      27    60.000000     7200     0.000000         234         NaN
# 27      28    98.000000    11478   200.000000        1218         NaN
# 28      29    47.000000    16321     0.000000        1277         NaN
# 29      30    60.000000     6324     0.000000           0         NaN
# 30      31    50.000000     8500     0.000000           0         NaN
# 31      32    70.049958     8544     0.000000           0         NaN
# 32      33    85.000000    11049     0.000000           0         NaN
# 33      34    70.000000    10552     0.000000        1018         NaN
# 34      35    60.000000     7313   246.000000        1153         NaN
# 35      36   108.000000    13418   132.000000           0         NaN
# 36      37   112.000000    10859     0.000000           0         NaN
# 37      38    74.000000     8532   650.000000        1213         NaN
# 38      39    68.000000     7922     0.000000         731         NaN
# 39      40    65.000000     6040     0.000000           0         NaN
# 40      41    84.000000     8658   101.000000         643         NaN
# 41      42   115.000000    16905     0.000000         967         NaN
# 42      43    70.049958     9180     0.000000         747         NaN
# 43      44    70.049958     9200     0.000000         280         NaN
# 44      45    70.000000     7945     0.000000         179         NaN
# 45      46    61.000000     7658   412.000000         456         NaN
# 46      47    48.000000    12822     0.000000        1351         NaN
# 47      48    84.000000    11096     0.000000          24         NaN
# 48      49    33.000000     4456     0.000000           0         NaN
# 49      50    66.000000     7742     0.000000         763         NaN
# 50      51    70.049958    13869     0.000000         182         NaN
# 51      52    52.000000     6240     0.000000           0         NaN
# 52      53   110.000000     8472     0.000000         104         NaN
# 53      54    68.000000    50271     0.000000        1810         NaN
# 54      55    60.000000     7134     0.000000         384         NaN
# 55      56   100.000000    10175   272.000000         490         NaN
# 56      57    24.000000     2645   456.000000         649         NaN
# 57      58    89.000000    11645     0.000000           0         NaN
# 58      59    66.000000    13682  1031.000000           0         NaN
# 59      60    60.000000     7200     0.000000         632         NaN
# 60      61    63.000000    13072     0.000000         941         NaN
# 61      62    60.000000     7200     0.000000           0         NaN
# 62      63    44.000000     6442   178.000000          24         NaN
# 63      64    50.000000    10300     0.000000           0         NaN
# 64      65    70.049958     9375   573.000000         739         NaN
# 65      66    76.000000     9591   344.000000           0         NaN
# 66      67    70.049958    19900   287.000000         912         NaN
# 67      68    72.000000    10665   167.000000        1013         NaN
# 68      69    47.000000     4608     0.000000           0         NaN
# 69      70    81.000000    15593     0.000000         603         NaN
# 70      71    95.000000    13651  1115.000000        1880         NaN
# 71      72    69.000000     7599     0.000000         565         NaN
# 72      73    74.000000    10141    40.000000           0         NaN
# 73      74    85.000000    10200   104.000000         320         NaN
# 74      75    60.000000     5790     0.000000           0         NaN
# 75      76    21.000000     1596     0.000000         462         NaN
# 76      77    70.049958     8475     0.000000         228         NaN
# 77      78    50.000000     8635     0.000000         336         NaN
# 78      79    72.000000    10778     0.000000           0         NaN
# 79      80    60.000000    10440     0.000000           0         NaN
# 80      81   100.000000    13000   576.000000         448         NaN
# 81      82    32.000000     4500   443.000000        1201         NaN
# 82      83    78.000000    10206   468.000000          33         NaN
# 83      84    80.000000     8892    66.000000           0         NaN
# 84      85    70.049958     8530    22.000000           0         NaN
# 85      86   121.000000    16059   284.000000           0         NaN
# 86      87   122.000000    11911     0.000000           0         NaN
# 87      88    40.000000     3951    76.000000           0         NaN
# 88      89   105.000000     8470     0.000000           0         NaN
# 89      90    60.000000     8070     0.000000         588         NaN
# 90      91    60.000000     7200     0.000000           0         NaN
# 91      92    85.000000     8500   203.000000         600         NaN
# 92      93    80.000000    13360     0.000000         713         NaN
# 93      94    60.000000     7200     0.000000        1046         NaN
# 94      95    69.000000     9337     0.000000         648         NaN
# 95      96    70.049958     9765    68.000000         310         NaN
# 96      97    78.000000    10264   183.000000        1162         NaN
# 97      98    73.000000    10921    48.000000         520         NaN
# 98      99    85.000000    10625     0.000000         108         NaN
# 99     100    77.000000     9320     0.000000         569         NaN
# 100    101    70.049958    10603    28.000000        1200         NaN
# 101    102    77.000000     9206   336.000000           0         NaN
# 102    103    64.000000     7018     0.000000           0         NaN
# 103    104    94.000000    10402     0.000000           0         NaN
# 104    105    70.049958     7758   600.000000         224         NaN
# 105    106    75.000000     9375   768.000000           0         NaN
# 106    107    60.000000    10800     0.000000           0         NaN
# 107    108    50.000000     6000     0.000000         104         NaN
# 108    109    85.000000     8500     0.000000           0         NaN
# 109    110   105.000000    11751   480.000000         705         NaN
# 110    111    75.000000     9525     0.000000         444         NaN
# 111    112    70.049958     7750     0.000000         250         NaN
# 112    113    77.000000     9965   220.000000         984         NaN
# 113    114    70.049958    21000   184.000000          35         NaN
# 114    115    61.000000     7259     0.000000         774         NaN
# 115    116    34.000000     3230  1129.000000         419         NaN
# 116    117    70.049958    11616   116.000000         170         NaN
# 117    118    74.000000     8536     0.000000           0         NaN
# 118    119    90.000000    12376     0.000000        1470         NaN
# 119    120    65.000000     8461     0.000000           0         NaN
# 120    121    70.049958    21453     0.000000         938         NaN
# 121    122    50.000000     6060     0.000000           0         NaN
# 122    123    75.000000     9464   135.000000         570         NaN
# 123    124    55.000000     7892     0.000000         300         NaN
# 124    125    48.000000    17043     0.000000           0         NaN
# 125    126    60.000000     6780     0.000000         490         NaN
# 126    127    70.049958     4928     0.000000         120         NaN
# 127    128    55.000000     4388     0.000000         116         NaN
# 128    129    69.000000     7590   266.000000         512         NaN
# 129    130    69.000000     8973    85.000000         567         NaN
# 130    131    88.000000    14200   309.000000         445         NaN
# 131    132    70.049958    12224    40.000000         695         NaN
# 132    133    75.000000     7388     0.000000         405         NaN
# 133    134    70.049958     6853   136.000000        1005         NaN
# 134    135    78.000000    10335     0.000000         570         NaN
# 135    136    80.000000    10400   288.000000           0         NaN
# 136    137    70.049958    10355   196.000000         695         NaN
# 137    138    82.000000    11070    70.000000           0         NaN
# 138    139    73.000000     9066   320.000000         668         NaN
# 139    140    65.000000    15426     0.000000         821         NaN
# 140    141    70.000000    10500     0.000000         432         NaN
# 141    142    78.000000    11645     0.000000        1300         NaN
# 142    143    71.000000     8520     0.000000         507         NaN
# 143    144    78.000000    10335   183.000000         679         NaN
# 144    145    70.000000     9100   336.000000        1332         NaN
# 145    146    24.000000     2522    50.000000           0         NaN
# 146    147    51.000000     6120     0.000000         209         NaN
# 147    148    70.049958     9505   180.000000           0         NaN
# 148    149    63.000000     7500   120.000000         680         NaN
# 149    150    70.049958     6240     0.000000           0         NaN
# 150    151   120.000000    10356     0.000000         716         NaN
# 151    152   107.000000    13891   436.000000        1400         NaN
# 152    153    70.049958    14803   252.000000         416         NaN
# 153    154    70.049958    13500     0.000000         429         NaN
# 154    155    84.000000    11340     0.000000           0         NaN
# 155    156    60.000000     9600     0.000000           0         NaN
# 156    157    60.000000     7200     0.000000           0         NaN
# 157    158    92.000000    12003    84.000000           0         NaN
# 158    159   100.000000    12552     0.000000         222         NaN
# 159    160   134.000000    19378   456.000000          57         NaN
# 160    161    70.049958    11120     0.000000         660         NaN
# 161    162   110.000000    13688   664.000000        1016         NaN
# 162    163    95.000000    12182   226.000000        1201         NaN
# 163    164    55.000000     5500     0.000000           0         NaN
# 164    165    40.000000     5400     0.000000         370         NaN
# 165    166    62.000000    10106     0.000000         351         NaN
# 166    167    70.049958    10708     0.000000         379         NaN
# 167    168    86.000000    10562   300.000000        1288         NaN
# 168    169    62.000000     8244     0.000000           0         NaN
# 169    170    70.049958    16669   653.000000           0         NaN
# 170    171    70.049958    12358     0.000000         360         NaN
# 171    172   141.000000    31770   112.000000         639         NaN
# 172    173    44.000000     5306     0.000000         495         NaN
# 173    174    80.000000    10197   491.000000         288         NaN
# 174    175    47.000000    12416   132.000000        1398         NaN
# 175    176    84.000000    12615     0.000000         477         NaN
# 176    177    97.000000    10029   268.000000         831         NaN
# 177    178    70.049958    13650     0.000000          57         NaN
# 178    179    63.000000    17423   748.000000        1904         NaN
# 179    180    60.000000     8520     0.000000           0         NaN
# 180    181    70.049958     2117   456.000000         436         NaN
# 181    182    54.000000     7588     0.000000         352         NaN
# 182    183    60.000000     9060    98.000000           0         NaN
# 183    184    63.000000    11426     0.000000           0         NaN
# 184    185    92.000000     7438     0.000000           0         NaN
# 185    186    90.000000    22950     0.000000           0         NaN
# 186    187    70.049958     9947     0.000000         611         NaN
# 187    188    60.000000    10410     0.000000           0         NaN
# 188    189    64.000000     7018   275.000000        1086         NaN
# 189    190    41.000000     4923     0.000000        1153         NaN
# 190    191    70.000000    10570     0.000000         297         NaN
# 191    192    70.049958     7472   138.000000         626         NaN
# 192    193    68.000000     9017     0.000000         560         NaN
# 193    194    24.000000     2522    50.000000           0         NaN
# 194    195    60.000000     7180     0.000000         390         NaN
# 195    196    24.000000     2280     0.000000         566         NaN
# 196    197    79.000000     9416   205.000000        1126         NaN
# 197    198   174.000000    25419     0.000000        1036         NaN
# 198    199    92.000000     5520     0.000000           0         NaN
# 199    200    76.000000     9591   262.000000        1088         NaN
# 200    201    80.000000     8546     0.000000           0         NaN
# 201    202    75.000000    10125     0.000000         641         NaN
# 202    203    50.000000     7000     0.000000         617         NaN
# 203    204    70.049958     4438   205.000000         662         NaN
# 204    205    50.000000     3500     0.000000         312         NaN
# 205    206    99.000000    11851     0.000000           0         NaN
# 206    207    40.000000    13673     0.000000           0         NaN
# 207    208    70.049958    12493     0.000000         419         NaN
# 208    209    70.049958    14364   128.000000        1065         NaN
# 209    210    75.000000     8250   260.000000         787         NaN
# 210    211    67.000000     5604     0.000000         468         NaN
# 211    212    83.000000    10420     0.000000          36         NaN
# 212    213    72.000000     8640     0.000000         822         NaN
# 213    214    43.000000    13568     0.000000         716         NaN
# 214    215    70.049958    10900   153.000000         378         NaN
# 215    216    72.000000    10011    64.000000         360         NaN
# 216    217    65.000000     8450   266.000000         946         NaN
# 217    218    57.000000     9906     0.000000           0         NaN
# 218    219    70.049958    15660   312.000000         341         NaN
# 219    220    43.000000     3010    16.000000          16         NaN
# 220    221    73.000000     8990     0.000000           0         NaN
# 221    222    70.049958     8068     0.000000           0         NaN
# 222    223    85.000000    11475     0.000000         550         NaN
# 223    224    70.000000    10500     0.000000         524         NaN
# 224    225   103.000000    13472   922.000000          56         NaN
# 225    226    21.000000     1680   142.000000           0         NaN
# 226    227    82.000000     9950   290.000000         565         NaN
# 227    228    21.000000     1869   127.000000         321         NaN
# 228    229    70.000000     8521     0.000000         842         NaN
# 229    230    43.000000     3182    16.000000          16         NaN
# 230    231    73.000000     8760   220.000000           0         NaN
# 231    232   174.000000    15138   506.000000         689         NaN
# 232    233    21.000000     1680   297.000000           0         NaN
# 233    234    75.000000    10650     0.000000         182         NaN
# 234    235    70.049958     7851   103.685262         625         NaN
# 235    236    21.000000     1680   604.000000         358         NaN
# 236    237    65.000000     8773    98.000000          24         NaN
# 237    238    70.049958     9453     0.000000         402         NaN
# 238    239    93.000000    12030   254.000000           0         NaN
# 239    240    52.000000     8741     0.000000          94         NaN
# 240    241    75.000000     9000    36.000000        1078         NaN
# 241    242    40.000000     3880     0.000000         329         NaN
# 242    243    63.000000     5000     0.000000           0         NaN
# 243    244    75.000000    10762     0.000000           0         NaN
# 244    245    70.049958     8880     0.000000         695         NaN
# 245    246    80.000000    10400   102.000000         929         NaN
# 246    247    69.000000     9142     0.000000           0         NaN
# 247    248    75.000000    11310     0.000000           0         NaN
# 248    249    72.000000    11317   101.000000           0         NaN
# 249    251    55.000000     5350     0.000000           0         NaN
# 250    252    44.000000     4750   481.000000        1573         NaN
# 251    253    65.000000     8366     0.000000           0         NaN
# 252    254    85.000000     9350   108.000000         270         NaN
# 253    255    70.000000     8400     0.000000         922         NaN
# 254    256    66.000000     8738   302.000000           0         NaN
# 255    257    64.000000     8791     0.000000         503         NaN
# 256    258    68.000000     8814   180.000000        1334         NaN
# 257    259    80.000000    12435   172.000000         361         NaN
# 258    260    70.000000    12702     0.000000           0         NaN
# 259    261   120.000000    19296   399.000000         672         NaN
# 260    262    69.000000     9588   270.000000           0         NaN
# 261    263    88.000000     8471    46.000000         506         NaN
# 262    264    50.000000     5500     0.000000         234         NaN
# 263    265    30.000000     5232     0.000000           0         NaN
# 264    266    78.000000    12090   210.000000         588         NaN
# 265    267    70.000000    11207     0.000000         714         NaN
# 266    268    60.000000     8400     0.000000         378         NaN
# 267    269    71.000000     6900     0.000000         403         NaN
# 268    270    70.049958     7917   174.000000         751         NaN
# 269    271    84.000000    10728     0.000000           0         NaN
# 270    272    73.000000    39104     0.000000         226         NaN
# 271    273    92.000000    11764   348.000000         524         NaN
# 272    274    80.000000     9600   183.000000         620         NaN
# 273    275    76.000000     8314     0.000000         546         NaN
# 274    276    55.000000     7264     0.000000           0         NaN
# 275    277   129.000000     9196     0.000000           0         NaN
# 276    278   140.000000    19138     0.000000         120         NaN
# 277    279   107.000000    14450   315.000000           0         NaN
# 278    280    83.000000    10005   299.000000         392         NaN
# 279    281    82.000000    11287   340.000000         421         NaN
# 280    282    60.000000     7200    68.000000         905         NaN
# 281    283    34.000000     5063   166.000000         904         NaN
# 282    284    74.000000     9612    72.000000           0         NaN
# 283    285    50.000000     8012     0.000000         430         NaN
# 284    286    35.000000     4251     0.000000           0         NaN
# 285    287    77.000000     9786     0.000000         600         NaN
# 286    288    70.049958     8125     0.000000         614         NaN
# 287    289    70.049958     9819    31.000000         450         NaN
# 288    290    60.000000     8730     0.000000           0         NaN
# 289    291   120.000000    15611     0.000000           0         NaN
# 290    292    55.000000     5687     0.000000         210         NaN
# 291    293    60.000000    11409     0.000000         292         NaN
# 292    294    70.049958    16659    34.000000         795         NaN
# 293    295    80.000000     9600   238.000000        1285         NaN
# 294    296    37.000000     7937     0.000000         819         NaN
# 295    297    75.000000    13710     0.000000         420         NaN
# 296    299    90.000000    11700   365.000000         384         NaN
# 297    300    80.000000    14000     0.000000           0         NaN
# 298    301    90.000000    15750    56.000000         841         NaN
# 299    302    66.000000    16226     0.000000         281         NaN
# 300    303   118.000000    13704   150.000000           0         NaN
# 301    304    70.000000     9800     0.000000         894         NaN
# 302    305    87.000000    18386     0.000000           0         NaN
# 303    306    80.000000    10386   246.000000        1464         NaN
# 304    307   116.000000    13474   246.000000         700         NaN
# 305    308    70.049958     7920     0.000000           0         NaN
# 306    309    70.049958    12342     0.000000         262         NaN
# 307    310    90.000000    12378     0.000000        1274         NaN
# 308    311    70.049958     7685   112.000000         518         NaN
# 309    312    50.000000     8000     0.000000         680         NaN
# 310    313    65.000000     7800     0.000000         507         NaN
# 311    315    60.000000     9600     0.000000          16         NaN
# 312    316    71.000000     7795     0.000000         425         NaN
# 313    317    94.000000    13005   278.000000         692         NaN
# 314    318    75.000000     9000     0.000000           0         NaN
# 315    319    90.000000     9900   256.000000         987         NaN
# 316    320    70.049958    14115   225.000000        1036         NaN
# 317    321   111.000000    16259   370.000000           0         NaN
# 318    322    99.000000    12099   388.000000         970         NaN
# 319    323    86.000000    10380   172.000000          28         NaN
# 320    324    49.000000     5820     0.000000         256         NaN
# 321    325    96.000000    11275   300.000000           0         NaN
# 322    326    50.000000     5000     0.000000         116         NaN
# 323    327    32.000000    10846     0.000000        1619         NaN
# 324    328    80.000000    11600   175.000000         565         NaN
# 325    329    70.049958    11888     0.000000           0         NaN
# 326    330    60.000000     6402     0.000000           0         NaN
# 327    331    70.049958    10624    84.000000          40         NaN
# 328    332    70.000000     8176     0.000000         846         NaN
# 329    333    85.000000    10655   296.000000        1124         NaN
# 330    334    59.000000     8198   146.000000         720         NaN
# 331    335    59.000000     9042     0.000000         828         NaN
# 332    337    86.000000    14157   200.000000        1249         NaN
# 333    338    70.000000     9135   113.000000         810         NaN
# 334    339    91.000000    14145     0.000000         213         NaN
# 335    340    66.000000    12400   176.000000         585         NaN
# 336    341    85.000000    14191     0.000000           0         NaN
# 337    342    60.000000     8400     0.000000           0         NaN
# 338    343    70.049958     8544   340.000000           0         NaN
# 339    344    63.000000     8849   616.000000          28         NaN
# 340    345    36.000000     2592     0.000000         129         NaN
# 341    346    65.000000     6435     0.000000           0         NaN
# 342    347    70.049958    12772     0.000000         498         NaN
# 343    348    70.049958    17600    30.000000        1270         NaN
# 344    349    36.000000     2448   106.000000         573         NaN
# 345    350    56.000000    20431   870.000000        1410         NaN
# 346    351    68.000000     7820   362.000000           0         NaN
# 347    352    70.049958     5271     0.000000        1082         NaN
# 348    353    60.000000     9084     0.000000         236         NaN
# 349    354    60.000000     8520     0.000000           0         NaN
# 350    355    60.000000     8400     0.000000         388         NaN
# 351    356   105.000000    11249     0.000000         334         NaN
# 352    357    70.049958     9248   106.000000         560         NaN
# 353    358    44.000000     4224     0.000000         874         NaN
# 354    359    92.000000     6930   120.000000         300         NaN
# 355    360    78.000000    12011   530.000000         956         NaN
# 356    361    70.049958     7540     0.000000         773         NaN
# 357    362    70.049958     9144     0.000000         399         NaN
# 358    363    64.000000     7301   500.000000           0         NaN
# 359    364    21.000000     1680   510.000000         162         NaN
# 360    365    70.049958    18800   120.000000         712         NaN
# 361    366    59.000000    10690     0.000000         456         NaN
# 362    367    70.049958     9500   247.000000         609         NaN
# 363    368   101.000000     9150   305.000000         371         NaN
# 364    369    78.000000     7800   200.000000         540         NaN
# 365    370    70.049958     9830     0.000000          72         NaN
# 366    371    70.049958     8121     0.000000           0         NaN
# 367    372    80.000000    17120     0.000000           0         NaN
# 368    373    50.000000     7175     0.000000         623         NaN
# 369    374    79.000000    10634     0.000000         428         NaN
# 370    375    65.000000     8200     0.000000           0         NaN
# 371    376    70.049958    10020     0.000000         350         NaN
# 372    377    57.000000     8846     0.000000         298         NaN
# 373    378   102.000000    11143     0.000000           0         NaN
# 374    379    88.000000    11394   350.000000        1445         NaN
# 375    380    60.000000     8123    16.000000           0         NaN
# 376    381    50.000000     5000     0.000000         218         NaN
# 377    382    60.000000     7200     0.000000           0         NaN
# 378    383    79.000000     9245     0.000000           0         NaN
# 379    384    60.000000     9000     0.000000           0         NaN
# 380    385    70.049958    53107     0.000000         985         NaN
# 381    386    43.000000     3182    16.000000          24         NaN
# 382    387    58.000000     8410     0.000000           0         NaN
# 383    388    72.000000     7200   255.000000         631         NaN
# 384    389    93.000000     9382   125.000000           0         NaN
# 385    390    96.000000    12474   272.000000        1280         NaN
# 386    391    50.000000     8405     0.000000         241         NaN
# 387    392    71.000000    12209     0.000000         690         NaN
# 388    393    70.049958     8339     0.000000           0         NaN
# 389    394    70.049958     7446     0.000000         266         NaN
# 390    395    60.000000    10134     0.000000           0         NaN
# 391    396    68.000000     9571     0.000000         739         NaN
# 392    397    60.000000     7200     0.000000         777         NaN
# 393    398    69.000000     7590   288.000000         540         NaN
# 394    399    60.000000     8967     0.000000           0         NaN
# 395    400    65.000000     8125   100.000000         812         NaN
# 396    401    38.000000    14963     0.000000         786         NaN
# 397    402    65.000000     8767     0.000000          24         NaN
# 398    403    60.000000    10200     0.000000           0         NaN
# 399    404    93.000000    12090   650.000000           0         NaN
# 400    405    70.049958    10364     0.000000           0         NaN
# 401    406    70.049958     9991     0.000000        1116         NaN
# 402    407    51.000000    10480     0.000000           0         NaN
# 403    408    63.000000    15576     0.000000           0         NaN
# 404    409   109.000000    14154   350.000000           0         NaN
# 405    410    85.000000    10800   100.000000         789         NaN
# 406    411    68.000000     9571     0.000000           0         NaN
# 407    412   100.000000    34650     0.000000        1056         NaN
# 408    413    70.049958     4403   432.000000         578         NaN
# 409    414    56.000000     8960     0.000000           0         NaN
# 410    415    59.000000    11228     0.000000          50         NaN
# 411    416    73.000000     8899     0.000000          24         NaN
# 412    417    74.000000     7844   203.000000         209         NaN
# 413    418    86.000000    22420     0.000000        1128         NaN
# 414    419    60.000000     8160     0.000000         312         NaN
# 415    420    65.000000     8450     0.000000         775         NaN
# 416    421    78.000000     7060   200.000000        1309         NaN
# 417    422    70.049958    16635   126.000000        1246         NaN
# 418    423   100.000000    21750     0.000000           0         NaN
# 419    424    80.000000     9200   473.000000         986         NaN
# 420    425    72.000000     9000    74.000000         616         NaN
# 421    426    60.000000     3378     0.000000           0         NaN
# 422    427    70.049958    12800   145.000000        1518         NaN
# 423    428    77.000000     8593     0.000000         288         NaN
# 424    429    64.000000     6762   108.000000         664         NaN
# 425    430   130.000000    11457     0.000000        1005         NaN
# 426    431    21.000000     1680   232.000000         387         NaN
# 427    432    60.000000     5586     0.000000           0         NaN
# 428    433    24.000000     1920   376.000000         471         NaN
# 429    434   100.000000    10839     0.000000           0         NaN
# 430    435    21.000000     1890     0.000000         495         NaN
# 431    436    43.000000    10667     0.000000         385         NaN
# 432    437    40.000000     4400     0.000000           0         NaN
# 433    438    50.000000     6000     0.000000           0         NaN
# 434    439    40.000000     4280     0.000000         365         NaN
# 435    440    67.000000    12354     0.000000           0         NaN
# 436    441   105.000000    15431   200.000000        1767         NaN
# 437    442    92.000000    12108   270.000000         133         NaN
# 438    443    52.000000     6240     0.000000           0         NaN
# 439    444    53.000000     3922    72.000000           0         NaN
# 440    445    70.000000     8750     0.000000         642         NaN
# 441    446    73.000000     9855     0.000000           0         NaN
# 442    447   137.000000    16492     0.000000         247         NaN
# 443    448    70.049958    11214     0.000000           0         NaN
# 444    449    50.000000     8600     0.000000           0         NaN
# 445    450    50.000000     6000     0.000000         331         NaN
# 446    451    70.000000     5684     0.000000           0         NaN
# 447    453    70.049958     9303    42.000000         742         NaN
# 448    454    75.000000     9000     0.000000           0         NaN
# 449    455    63.000000     9297     0.000000        1606         NaN
# 450    456    80.000000     9600   320.000000         916         NaN
# 451    457    34.000000     4571     0.000000           0         NaN
# 452    458    70.049958    53227     0.000000        1116         NaN
# 453    459    70.049958     5100     0.000000           0         NaN
# 454    460    70.049958     7015   161.000000         185         NaN
# 455    461    75.000000     8004   110.000000         544         NaN
# 456    462    60.000000     7200     0.000000         350         NaN
# 457    463    60.000000     8281     0.000000         553         NaN
# 458    464    74.000000    11988     0.000000         326         NaN
# 459    465    60.000000     8430   136.000000         616         NaN
# 460    466    70.049958     3072    18.000000           0         NaN
# 461    467    85.000000    10628     0.000000         778         NaN
# 462    468    79.000000     9480   224.000000         386         NaN
# 463    469    98.000000    11428   248.000000           0         NaN
# 464    470    76.000000     9291   120.000000         426         NaN
# 465    471    70.049958     6820     0.000000         368         NaN
# 466    472    92.000000    11952     0.000000           0         NaN
# 467    473    35.000000     3675    80.000000         459         NaN
# 468    474   110.000000    14977   304.000000        1350         NaN
# 469    475    41.000000     5330     0.000000        1196         NaN
# 470    476    80.000000     8480     0.000000         630         NaN
# 471    477    75.000000    13125   215.000000         994         NaN
# 472    478   105.000000    13693   772.000000           0         NaN
# 473    479    79.000000    10637   336.000000        1288         NaN
# 474    480    50.000000     5925   435.000000         168         NaN
# 475    481    98.000000    16033   378.000000        1261         NaN
# 476    482    72.000000    11846   562.000000        1567         NaN
# 477    483    50.000000     2500     0.000000         299         NaN
# 478    484    32.000000     4500   116.000000         897         NaN
# 479    485    70.049958     7758     0.000000         588         NaN
# 480    486    80.000000     9600     0.000000         607         NaN
# 481    487    79.000000    10289   168.000000         836         NaN
# 482    488    70.000000    12243     0.000000         998         NaN
# 483    489    60.000000    10800     0.000000         664         NaN
# 484    490    21.000000     1526     0.000000         515         NaN
# 485    491    70.049958     2665     0.000000           0         NaN
# 486    492    79.000000     9490     0.000000         403         NaN
# 487    493   105.000000    15578     0.000000           0         NaN
# 488    494    70.000000     7931     0.000000         374         NaN
# 489    495    50.000000     5784     0.000000           0         NaN
# 490    496    60.000000     7879     0.000000         495         NaN
# 491    497    70.049958    12692     0.000000        1231         NaN
# 492    498    60.000000     9120     0.000000         329         NaN
# 493    499    65.000000     7800    89.000000         450         NaN
# 494    500    70.000000     7535     0.000000         111         NaN
# 495    501    21.000000     1890   285.000000         356         NaN
# 496    502    75.000000     9803     0.000000         400         NaN
# 497    503    70.000000     9170     0.000000         698         NaN
# 498    504   100.000000    15602     0.000000        1247         NaN
# 499    505    24.000000     2308     0.000000         257         NaN
# 500    506    60.000000     7596   360.000000           0         NaN
# 501    507    80.000000     9554   125.000000         380         NaN
# 502    508    75.000000     7862     0.000000          27         NaN
# 503    509    60.000000     9600     0.000000         141         NaN
# 504    510    80.000000     9600   132.000000         991         NaN
# 505    511    75.000000    14559    70.000000         650         NaN
# 506    512    40.000000     6792    94.000000           0         NaN
# 507    513    70.000000     9100     0.000000         521         NaN
# 508    514    71.000000     9187     0.000000         336         NaN
# 509    515    55.000000    10594     0.000000           0         NaN
# 510    516    94.000000    12220   305.000000        1436         NaN
# 511    517    70.049958    10448   333.000000           0         NaN
# 512    518    79.000000    10208   921.000000           0         NaN
# 513    519    70.049958     9531     0.000000         706         NaN
# 514    520    53.000000    10918     0.000000           0         NaN
# 515    521    60.000000    10800     0.000000           0         NaN
# 516    522    90.000000    11988     0.000000         777         NaN
# 517    523    50.000000     5000     0.000000         399         NaN
# 518    525    95.000000    11787   594.000000         719         NaN
# 519    526    62.000000     7500     0.000000           0         NaN
# 520    527    70.000000    13300     0.000000         377         NaN
# 521    528    67.000000    14948   268.000000        1330         NaN
# 522    529    58.000000     9098     0.000000         348         NaN
# 523    530    70.049958    32668   103.685262        1219         NaN
# 524    531    85.000000    10200   219.000000         783         NaN
# 525    532    60.000000     6155     0.000000           0         NaN
# 526    533    60.000000     7200     0.000000           0         NaN
# 527    534    50.000000     5000     0.000000           0         NaN
# 528    535    74.000000     9056     0.000000           0         NaN
# 529    536    70.000000     7000     0.000000         969         NaN
# 530    537    57.000000     8924     0.000000           0         NaN
# 531    538    70.049958    12735     0.000000         600         NaN
# 532    539    70.049958    11553   188.000000         673         NaN
# 533    540    70.049958    11423   479.000000        1358         NaN
# 534    541    85.000000    14601   584.000000        1260         NaN
# 535    542    70.049958    11000    72.000000           0         NaN
# 536    543    78.000000    10140     0.000000         144         NaN
# 537    544    34.000000     4058   182.000000         584         NaN
# 538    545    58.000000    17104     0.000000         554         NaN
# 539    546    70.049958    13837   178.000000        1002         NaN
# 540    547    70.000000     8737     0.000000         300         NaN
# 541    548    54.000000     7244     0.000000         619         NaN
# 542    549    49.000000     8235     0.000000         180         NaN
# 543    550    75.000000     9375     0.000000           0         NaN
# 544    551    53.000000     4043     0.000000         559         NaN
# 545    552    50.000000     6000     0.000000         308         NaN
# 546    553    87.000000    11146   250.000000           0         NaN
# 547    554    67.000000     8777     0.000000           0         NaN
# 548    555    85.000000    10625   292.000000         866         NaN
# 549    556    58.000000     6380     0.000000           0         NaN
# 550    557    69.000000    14850     0.000000         895         NaN
# 551    558    60.000000    11040     0.000000         637         NaN
# 552    559    57.000000    21872     0.000000         604         NaN
# 553    560    70.049958     3196    18.000000           0         NaN
# 554    561    70.049958    11341   180.000000        1302         NaN
# 555    562    77.000000    10010     0.000000        1071         NaN
# 556    563    63.000000    13907     0.000000         290         NaN
# 557    564    66.000000    21780     0.000000           0         NaN
# 558    565    70.049958    13346     0.000000         728         NaN
# 559    566    66.000000     6858     0.000000           0         NaN
# 560    567    77.000000    11198   245.000000           0         NaN
# 561    568    70.000000    10171   168.000000           2         NaN
# 562    569    79.000000    12327     0.000000        1441         NaN
# 563    570    70.049958     7032     0.000000         943         NaN
# 564    571    74.000000    13101   108.000000         231         NaN
# 565    572    60.000000     7332   207.000000         414         NaN
# 566    573    83.000000    13159     0.000000           0         NaN
# 567    574    76.000000     9967     0.000000           0         NaN
# 568    575    70.000000    10500    82.000000         349         NaN
# 569    576    80.000000     8480     0.000000         442         NaN
# 570    577    52.000000     6292     0.000000           0         NaN
# 571    578    96.000000    11777    97.000000         328         NaN
# 572    579    34.000000     3604     0.000000           0         NaN
# 573    580    81.000000    12150   335.000000           0         NaN
# 574    581    70.049958    14585    85.000000         594         NaN
# 575    582    98.000000    12704   306.000000           0         NaN
# 576    583    81.000000    11841   104.000000         816         NaN
# 577    584    75.000000    13500     0.000000           0         NaN
# 578    585    51.000000     6120     0.000000           0         NaN
# 579    586    88.000000    11443   208.000000        1460         NaN
# 580    587    55.000000    10267     0.000000         210         NaN
# 581    588    74.000000     8740     0.000000         672         NaN
# 582    589    65.000000    25095     0.000000        1324         NaN
# 583    590    50.000000     9100     0.000000           0         NaN
# 584    591    64.000000     8320     0.000000         490         NaN
# 585    592    97.000000    13478   420.000000        1338         NaN
# 586    593    60.000000     6600     0.000000         816         NaN
# 587    594    70.049958     4435   170.000000         685         NaN
# 588    595    88.000000     7990     0.000000           0         NaN
# 589    596    69.000000    11302   238.000000        1422         NaN
# 590    597    60.000000     3600     0.000000           0         NaN
# 591    598    53.000000     3922    72.000000           0         NaN
# 592    599    80.000000    12984   459.000000        1283         NaN
# 593    600    24.000000     1950     0.000000          81         NaN
# 594    601    74.000000    10927   280.000000         546         NaN
# 595    602    50.000000     9000     0.000000           0         NaN
# 596    603    80.000000    10041     0.000000         789         NaN
# 597    604    30.000000     3182     0.000000           0         NaN
# 598    605    88.000000    12803    99.000000         922         NaN
# 599    606    85.000000    13600   176.000000         454         NaN
# 600    607    82.000000    12464     0.000000         732         NaN
# 601    608    78.000000     7800     0.000000         603         NaN
# 602    609    78.000000    12168     0.000000         428         NaN
# 603    610    61.000000     7943   192.000000         903         NaN
# 604    611    70.049958    11050   204.000000         904         NaN
# 605    612    70.049958    10395   233.000000         605         NaN
# 606    613    70.049958    11885   108.000000         990         NaN
# 607    614    70.000000     8402     0.000000         206         NaN
# 608    615    21.000000     1491     0.000000         150         NaN
# 609    616    80.000000     8800   156.000000         763         NaN
# 610    617    70.049958     7861     0.000000         457         NaN
# 611    618    59.000000     7227     0.000000           0         NaN
# 612    619    90.000000    11694   452.000000          48         NaN
# 613    620    85.000000    12244   226.000000         871         NaN
# 614    621    45.000000     8248     0.000000          41         NaN
# 615    622    90.000000    10800     0.000000         956         NaN
# 616    623    71.000000     7064   153.000000         560         NaN
# 617    624    70.049958     2117   513.000000         420         NaN
# 618    625    80.000000    10400   288.000000         247         NaN
# 619    626    87.000000    10000   261.000000           0         NaN
# 620    627    70.049958    12342     0.000000           0         NaN
# 621    628    80.000000     9600   164.000000         674         NaN
# 622    629    70.000000    11606   192.000000         650         NaN
# 623    630    82.000000     9020   259.000000         624         NaN
# 624    631    50.000000     9000     0.000000           0         NaN
# 625    632    34.000000     4590   108.000000          24         NaN
# 626    633    85.000000    11900   209.000000         822         NaN
# 627    634    80.000000     9250     0.000000         480         NaN
# 628    635    64.000000     6979     0.000000        1056         NaN
# 629    636    60.000000    10896     0.000000         256         NaN
# 630    637    51.000000     6120     0.000000           0         NaN
# 631    638    50.000000     6000     0.000000           0         NaN
# 632    639    67.000000     8777     0.000000           0         NaN
# 633    640    53.000000     3982     0.000000        1154         NaN
# 634    641    62.000000    12677   472.000000        1218         NaN
# 635    642    70.049958     7050     0.000000         738         NaN
# 636    643    75.000000    13860     0.000000        1410         NaN
# 637    644    80.000000    10793   263.000000         493         NaN
# 638    645    85.000000     9187   162.000000        1121         NaN
# 639    646    70.049958    10530     0.000000         282         NaN
# 640    647    60.000000     7200     0.000000           0         NaN
# 641    648    85.000000    10452   216.000000         500         NaN
# 642    649    70.000000     7700   351.000000           0         NaN
# 643    650    21.000000     1936     0.000000         131         NaN
# 644    651    65.000000     8125   103.685262           0         NaN
# 645    652    60.000000     9084     0.000000           0         NaN
# 646    653    70.000000     8750     0.000000           0         NaN
# 647    654    60.000000    10320     0.000000           0         NaN
# 648    655    91.000000    10437   660.000000        1696         NaN
# 649    656    21.000000     1680   381.000000           0         NaN
# 650    657    72.000000    10007    54.000000         806         NaN
# 651    658    60.000000     7200     0.000000           0         NaN
# 652    659    78.000000    17503     0.000000           0         NaN
# 653    660    75.000000     9937     0.000000         637         NaN
# 654    661    70.049958    12384   233.000000           0         NaN
# 655    662    52.000000    46589   528.000000        1361         NaN
# ...
